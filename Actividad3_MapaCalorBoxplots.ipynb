# %% [markdown]
# # Actividad 3
# **Marco Iván Pacheco Martínez**

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\HP\anaconda3\envs\TC2001S\AnaliticaTC1002S\retoAnalitica

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
os.getcwd()
# Out:
# 'C:\\Users\\HP\\anaconda3\\envs\\TC2001S\\AnaliticaTC1002S\\retoAnalitica'

# %%
df = pd.read_csv("covid19_tweets.csv")

# %%
df.head()
# Out:
#          user_name         user_location  \
# 0           ᏉᎥ☻լꂅϮ            astroworld
# 1    Tom Basile 🇺🇸          New York, NY
# 2  Time4fisticuffs      Pewee Valley, KY
# 3      ethel mertz  Stuck in the Middle
# 4         DIPR-J&K     Jammu and Kashmir
#
#                                     user_description         user_created  \
# 0  wednesday addams as a disney princess keepin i...  2017-05-26 05:46:42
# 1  Husband, Father, Columnist & Commentator. Auth...  2009-04-16 20:06:23
# 2  #Christian #Catholic #Conservative #Reagan #Re...  2009-02-28 18:57:41
# 3  #Browns #Indians #ClevelandProud #[]_[] #Cavs ...  2019-03-07 01:45:06
# 4  🖊️Official Twitter handle of Department of Inf...  2017-02-12 06:45:15
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0             624           950            18775          False
# 1            2253          1677               24           True
# 2            9275          9525             7254          False
# ...

# %%
df.tail()
# Out:
#                       user_name  user_location  \
# 74431             Laura Wolfrom  Lexington, KY
# 74432  Professor Tonya M. Evans  😷 #stayathome
# 74433        People's Daily app    北京, 中华人民共和国
# 74434                     M0ser            NaN
# 74435    Your Friend & Sabre ⚔️    Chicago, IL
#
#                                         user_description         user_created  \
# 74431            The only things I collect are memories.  2010-09-24 02:01:15
# 74432  Law Prof @DickinsonLaw & Entrepreneur | Crypto...  2013-05-14 20:15:24
# 74433  Our mission is to provide news and perspective...  2018-02-04 12:36:42
# 74434  Reagan conservative and attorney raised in the...  2014-02-18 03:46:28
# 74435  My spectral decomposition has a significant da...  2016-12-19 19:55:00
#
#        user_followers  user_friends  user_favourites  user_verified  \
# 74431              85           586             1902          False
# 74432            4289          1066            53569          False
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=74436, step=1)

# %%
df.columns
# Out:
# Index(['user_name', 'user_location', 'user_description', 'user_created',
#        'user_followers', 'user_friends', 'user_favourites', 'user_verified',
#        'date', 'text', 'hashtags', 'source', 'is_retweet'],
#       dtype='object')

# %%
df.sort_index(axis = 1,ascending = True)
# Out:
#                       date                                 hashtags  \
# 0      2020-07-25 12:27:21                                      NaN
# 1      2020-07-25 12:27:17                                      NaN
# 2      2020-07-25 12:27:14                              ['COVID19']
# 3      2020-07-25 12:27:10                              ['COVID19']
# 4      2020-07-25 12:27:08        ['CoronaVirusUpdates', 'COVID19']
# ...                    ...                                      ...
# 74431  2020-08-04 03:13:29            ['COVID19', 'QuarantineLife']
# 74432  2020-08-04 03:13:26  ['TechIntersect', 'Bitcoin', 'COVID19']
# 74433  2020-08-04 03:13:22                    ['China', 'Xinjiang']
# 74434  2020-08-04 03:13:19                              ['COVID19']
# 74435  2020-08-04 03:13:15       ['COVID19', 'Hydroxycholoroquine']
#
#        is_retweet               source  \
# 0           False   Twitter for iPhone
# 1           False  Twitter for Android
# ...

# %%
#Contar los objetos
df.count()
# Out:
# user_name           74436
# user_location       59218
# user_description    70079
# user_created        74436
# user_followers      74436
# user_friends        74436
# user_favourites     74436
# user_verified       74436
# date                74436
# text                74436
# hashtags            53002
# source              74424
# is_retweet          74436
# dtype: int64

# %%
#Ordenar por variables
df.sort_values(by="user_favourites")
# Out:
#                                user_name      user_location  \
# 51507                               NDTV              India
# 27598                 The United Express                NaN
# 27621  Countries Without Coronavirus Bot                NaN
# 27625            Social Distance Warrior                NaN
# 27628                      Isolation Bot                NaN
# ...                                  ...                ...
# 62200               paolo ignazio marong                NaN
# 69943               paolo ignazio marong                NaN
# 70610               paolo ignazio marong                NaN
# 71764               paolo ignazio marong                NaN
# 14504                Chelsea Anderson.♥️  South Dakota, USA
#
#                                         user_description         user_created  \
# 51507  Breaking news alerts from India.\n\nInstagram:...  2009-05-01 20:34:48
# 27598  The United Express is a united venture by jour...  2019-11-06 14:12:20
# ...

# %%
df.dtypes
# Out:
# user_name           object
# user_location       object
# user_description    object
# user_created        object
# user_followers       int64
# user_friends         int64
# user_favourites      int64
# user_verified         bool
# date                object
# text                object
# hashtags            object
# source              object
# is_retweet            bool
# dtype: object

# %%
df['user_followers'].describe()
# Out:
# count    7.443600e+04
# mean     1.059513e+05
# std      8.222900e+05
# min      0.000000e+00
# 25%      1.660000e+02
# 50%      9.600000e+02
# 75%      5.148000e+03
# max      1.389284e+07
# Name: user_followers, dtype: float64

# %%
df['user_favourites'].describe()
# Out:
# count    7.443600e+04
# mean     1.529747e+04
# std      4.668971e+04
# min      0.000000e+00
# 25%      2.200000e+02
# 50%      1.927000e+03
# 75%      1.014800e+04
# max      2.047197e+06
# Name: user_favourites, dtype: float64

# %%
df['user_friends'].describe()
# Out:
# count     74436.000000
# mean       2154.721170
# std        9365.587474
# min           0.000000
# 25%         153.000000
# 50%         552.000000
# 75%        1780.250000
# max      497363.000000
# Name: user_friends, dtype: float64

# %%
df['text'].describe()
# Out:
# count                                                 74436
# unique                                                74312
# top       Greenland has no active cases of the novel cor...
# freq                                                      6
# Name: text, dtype: object

# %%
sns.boxplot(data=df["user_followers"],showfliers = False)
# Out:
# <AxesSubplot:>
